# %%
import pandas as pd
import random
import numpy as np
random.seed(2022)
np.random.seed(2022)
df = pd.read_csv("../../data/pretrain/disgenet_dda.csv")

# %%
df = df[["diseaseId1","diseaseId2","diseaseDes1","diseaseDes2"]]
df = df.dropna()
df["key1"] = df["diseaseId1"]+df["diseaseId2"]
df["key2"] = df["diseaseId2"]+df["diseaseId1"]
df.head()
# Out:
#   diseaseId1 diseaseId2                                        diseaseDes1  \
# 0   C0000737   C0000731  An unpleasant sensation characterized by physi...
# 1   C0005745   C0000731  The upper eyelid margin is positioned 3 mm or ...
# 2   C0006325   C0000731  Bruxism is characterized by the grinding of th...
# 3   C0007642   C0000731  A bacterial infection and inflammation of the ...
# 4   C0009806   C0000731       Infrequent or difficult evacuation of feces.
#
#                   diseaseDes2              key1              key2
# 0  Distention of the abdomen.  C0000737C0000731  C0000731C0000737
# 1  Distention of the abdomen.  C0005745C0000731  C0000731C0005745
# 2  Distention of the abdomen.  C0006325C0000731  C0000731C0006325
# 3  Distention of the abdomen.  C0007642C0000731  C0000731C0007642
# 4  Distention of the abdomen.  C0009806C0000731  C0000731C0009806

# %%
disease_dict = {}
for _,item in df.iterrows():
    disease_dict[item["diseaseId1"]]=item["diseaseDes1"]

# %%
disease_ids = list(set(df.diseaseId1.unique()).union(df.diseaseId2.unique()))
len(disease_ids)
# Out:
# 14403

# %%
keys = (set(df.key1.unique()).union(df.key2.unique()))

# %%
total_example_n = 4096+1024+1024
negative_example_n = total_example_n//2
positive_example_n = total_example_n - negative_example_n
df_sample = df.sample(positive_example_n)

# %%
feasible_negatives = []
while True:
    id1, id2 = random.sample(disease_ids, 2)
    if id1+id2 not in keys:
        feasible_negatives.append(id1+id2)
    if len(feasible_negatives)==negative_example_n:
        break

# %%
feasible_negatives = [[key[:8],key[8:]]for key in feasible_negatives]

# %%
df_sample["label"]=1
df_sample = df_sample[["diseaseId1","diseaseId2","diseaseDes1","diseaseDes2","label"]]
df_sample.head()
# Out:
#         diseaseId1 diseaseId2  \
# 1474484   C1843075   C1835671
# 508690    C0002949   C0032914
# 1518880   C0426415   C1850049
# 952600    C0027651   C0282313
# 997910    C0085261   C0345905
#
#                                                diseaseDes1  \
# 1474484  A rare hereditary motor and sensory neuropathy...
# 508690   A separation (dissection) of the layers of an ...
# 1518880  Distance between subnasale and pronasale more ...
# 952600   An organ or organ-system abnormality that cons...
# 997910   Proteus syndrome is characterized by progressi...
#
#                                                diseaseDes2  label
# 1474484  #8208;normal nerve conduction velocities. Addi...      1
# 508690   Preeclampsia, which along with chronic hyperte...      1
# 1518880  Clinodactyly refers to a bending or curvature ...      1
# 952600   cellular state in which there is evidence of i...      1
# 997910   A carcinoma that arises from the intrahepatic ...      1

# %%
diseaseId1_list = []
diseaseId2_list = []
diseaseDes1_list = []
diseaseDes2_list = []
for diseaseId1,diseaseId2 in feasible_negatives:
    diseaseId1_list.append(diseaseId1)
    diseaseId2_list.append(diseaseId2)
    diseaseDes1_list.append(disease_dict[diseaseId1])
    diseaseDes2_list.append(disease_dict[diseaseId2])

# %%
label_list = [0]*len(diseaseDes2_list)

# %%
pd.DataFrame({
    "diseaseId1":diseaseId1_list,
    "diseaseId2":diseaseId2_list,
    "diseaseDes1":diseaseDes1_list,
    "diseaseDes2":diseaseDes2_list,
    "label":label_list,
})
df_sample = df_sample.append(pd.DataFrame({
    "diseaseId1":diseaseId1_list,
    "diseaseId2":diseaseId2_list,
    "diseaseDes1":diseaseDes1_list,
    "diseaseDes2":diseaseDes2_list,
    "label":label_list,
}))
df_sample
# Out:
#         diseaseId1 diseaseId2  \
# 1474484   C1843075   C1835671
# 508690    C0002949   C0032914
# 1518880   C0426415   C1850049
# 952600    C0027651   C0282313
# 997910    C0085261   C0345905
# ...            ...        ...
# 3067      C0419415   C4316787
# 3068      C4552070   C4310712
# 3069      C2931401   C1857389
# 3070      C0000822   C4017089
# 3071      C0085700   C4551964
#
#                                                diseaseDes1  \
# 1474484  A rare hereditary motor and sensory neuropathy...
# 508690   A separation (dissection) of the layers of an ...
# 1518880  Distance between subnasale and pronasale more ...
# 952600   An organ or organ-system abnormality that cons...
# 997910   Proteus syndrome is characterized by progressi...
# ...                                                    ...
# 3067                                          Birth length
# 3068     Primary pulmonary arterial hypertension is a r...
# 3069                               Long QT syndrome type 3
# 3070                                       Abortion, Tubal
# 3071     Pathological processes involving the chondral ...
#
#                                                diseaseDes2  label
# 1474484  #8208;normal nerve conduction velocities. Addi...      1
# 508690   Preeclampsia, which along with chronic hyperte...      1
# 1518880  Clinodactyly refers to a bending or curvature ...      1
# 952600   cellular state in which there is evidence of i...      1
# 997910   A carcinoma that arises from the intrahepatic ...      1
# ...                                                    ...    ...
# 3067     A rare, primary bone dysplasia characterized b...      0
# 3068     Developmental and epileptic encephalopathy-43 ...      0
# 3069                                    Cystinuria, Type B      0
# 3070                         LONG QT SYNDROME 1, RECESSIVE      0
# 3071     HGPPS is an autosomal recessive neurologic dis...      0
#
# [6144 rows x 5 columns]

# %%
df_sample = df_sample.sample(frac=1)
df_sample = df_sample.reset_index()
df_sample.head()
# Out:
#      index diseaseId1 diseaseId2  \
# 0      724   C3809872   C1859775
# 1     1855   C0206710   C0238198
# 2     2707   C0751733   C4022428
# 3  1329138   C0038356   C0887800
# 4   215821   C1257931   C0014859
#
#                                          diseaseDes1  \
# 0  Any periventricular nodular heterotopia in whi...
# 1  A neoplastic proliferation of basal cells in t...
# 2                 Degenerative Diseases, Spinal Cord
# 3  A tumor (abnormal growth of tissue) of the sto...
# 4        Tumor or cancer of the human MAMMARY GLAND.
#
#                                          diseaseDes2  label
# 0  Underdevelopment of the anterior pituitary gland.      0
# 1  Gastrointestinal stromal tumors are mesenchyma...      0
# 2           Unilateral conductive hearing impairment      0
# 3          Psychogenic Inversion of Circadian Rhythm      1
# 4  A tumor (abnormal growth of tissue) of the eso...      1

# %%
df_sample_train = df_sample.iloc[:4096]
df_sample_valid = df_sample.iloc[4096:4096+1024]
df_sample_test = df_sample.iloc[4096+1024:]

# %%
df_sample_train.to_csv("../../data/downstream/disgenet_dda_6k_train.csv",index=None)
df_sample_valid.to_csv("../../data/downstream/disgenet_dda_6k_valid.csv",index=None)
df_sample_test.to_csv("../../data/downstream/disgenet_dda_6k_test.csv",index=None)

# %%
df_sample_valid
# Out:
#         index diseaseId1 diseaseId2  \
# 4096      917   C0270969   C0206731
# 4097  1109364   C0086692   C0521174
# 4098      367   C0030437   C0086647
# 4099     1236   C1857569   C3275476
# 4100   692493   C3714644   C0151779
# ...       ...        ...        ...
# 5115   886949   C0015695   C0265326
# 5116   264633   C0031511   C0018923
# 5117   612100   C0007102   C0041755
# 5118   541279   C0027051   C0035317
# 5119  1412881   C0205650   C1384666
#
#                                             diseaseDes1  \
# 4096                            ) gene may be involved.
# 4097  A neoplasm which is characterized by the absen...
# 4098                            Parakeratosis Variegata
# 4099  Corneal endothelial dystrophy is characterized...
# 4100  A tumor (abnormal growth of tissue) of the thy...
# ...                                                 ...
# 5115  Lipid infiltration of the hepatic parenchymal ...
# 5116  Hereditary paraganglioma-pheochromocytoma (PGL...
# 5117  A primary or metastatic malignant neoplasm tha...
# 5118  Necrosis of the myocardium caused by an obstru...
# 5119  An adenoma characterized by the presence of pa...
#
#                                             diseaseDes2  label
# 4096  Angiofibroma consist of many often dilated ves...      0
# 4097                                 Microcalcification      1
# 4098  Mucopolysaccharidosis type III (MPS III) is a ...      0
# 4099  X-linked dominant chondrodysplasia Chassaing-L...      0
# 4100            The presence of a melanoma of the skin.      1
# ...                                                 ...    ...
# 5115  The PTEN hamartoma tumor syndrome (PHTS) inclu...      1
# 5116  A rare vascular tumor characterized by a malig...      1
# 5117  An unpleasant or harmful reaction resulting fr...      1
# 5118            Hemorrhage occurring within the retina.      1
# 5119  A decreased magnitude of the sensory perceptio...      1
#
# [1024 rows x 6 columns]
